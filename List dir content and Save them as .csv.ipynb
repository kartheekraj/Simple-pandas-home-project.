# %%
import os
import pandas as pd

# %%
os.chdir(str(input("Enter the dirctory path "))) #Copy the path of the folder that you need to paste

print(os.getcwd())

df = pd.DataFrame(os.listdir())
# Out:
# Enter the dirctory path E:\\MOVIES\\Missalaneous
# E:\MOVIES\Missalaneous

# %%
df.head() #List the header the first 5 rows
# Out:
#                                    0
# 0           127 Hours (2010) [1080p]
# 1           A Christmas Carol (2009)
# 2  Anomalisa (2015) [1080p] [YTS.AG]
# 3             Birdman (2014) [1080p]
# 4       Blood Diamond (2006) [1080p]

# %%
df.columns #check the current columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
#wrting the file to a CSV:
df.to_csv('movies_list.csv', sep='\t') #this would be created in the current working directory

# %%
#Importing the new CSV:
df_new = pd.read_csv('movies_list.csv')

# %%
df_new
# Out:
#                                                   \t0
# 0                         0\t127 Hours (2010) [1080p]
# 1                         1\tA Christmas Carol (2009)
# 2                2\tAnomalisa (2015) [1080p] [YTS.AG]
# 3                           3\tBirdman (2014) [1080p]
# 4                     4\tBlood Diamond (2006) [1080p]
# 5                5\tBody Heat (1981) [1080p] [YTS.AG]
# 6          6\tBridge Of Spies (2015) [1080p] [YTS.AG]
# 7                              7\tBroken Arrow (1996)
# 8               8\tCatch Me If You Can (2002) - 1080p
# 9                           9\tChappie (2015) [1080p]
# 10                       10\tChronicle (2012) [1080p]
# 11             11\tConcussion (2015) [1080p] [YTS.AG]
# 12                12\tEdge of Tomorrow (2014) [1080p]
# 13                      13\tFight Club (1999) [1080p]
# 14                           14\tFocus (2015) [1080p]
# 15                               15\tFootloose (2011)
# ...

# %%
#To Change the columns of the database 
df_cols = ['Movie name']

# %%
df_new.columns = df_cols

# %%
df_new
# Out:
#                                            Movie name
# 0                         0\t127 Hours (2010) [1080p]
# 1                         1\tA Christmas Carol (2009)
# 2                2\tAnomalisa (2015) [1080p] [YTS.AG]
# 3                           3\tBirdman (2014) [1080p]
# 4                     4\tBlood Diamond (2006) [1080p]
# 5                5\tBody Heat (1981) [1080p] [YTS.AG]
# 6          6\tBridge Of Spies (2015) [1080p] [YTS.AG]
# 7                              7\tBroken Arrow (1996)
# 8               8\tCatch Me If You Can (2002) - 1080p
# 9                           9\tChappie (2015) [1080p]
# 10                       10\tChronicle (2012) [1080p]
# 11             11\tConcussion (2015) [1080p] [YTS.AG]
# 12                12\tEdge of Tomorrow (2014) [1080p]
# 13                      13\tFight Club (1999) [1080p]
# 14                           14\tFocus (2015) [1080p]
# 15                               15\tFootloose (2011)
# ...
